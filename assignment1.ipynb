# %%
import numpy as np
import matplotlib.pyplot as plot
import pandas as pd
from apyori import apriori

# %%
store_data = pd.read_csv('C:\\Users\\yaoli\\OneDrive\\Desktop\\Q8b.csv',header=None)
print (store_data)
print("#########################################################################")
num_records= len(store_data)
print("\nData length is:",num_records)
# Out:
#                0             1                    2                    3
# 0   Rechargeable         Stand       Travel Storage    Battery Indicator
# 1         Manual  Head Storage  Built-in Toothpaste    Battery Indicator
# 2         Manual  Rechargeable                Stand    Battery Indicator
# 3         Manual         Timer         Rechargeable                Stand
# 4         Manual      Warranty          Attachments           Extra Head
# 5         Manual         Style                Stand       Travel Storage
# 6         Manual    Dual Speed             Warranty           Extra Head
# 7        Battery         Timer                Style                Stand
# 8         Manual  Rechargeable                Stand    Battery Indicator
# 9         Manual  Rechargeable                Style                Stand
# 10        Manual  Rechargeable                Stand           Dual Speed
# 11        Manual         Timer         Rechargeable                Style
# 12        Manual  Rechargeable                Style                Stand
# 13       Battery    Dual Speed              Charity          Attachments
# 14        Manual  Rechargeable           Dual Speed  Built-in Toothpaste
# 15        Manual  Rechargeable       Travel Storage           Extra Head
# 16        Manual  Rechargeable    Battery Indicator           Extra Head
# 17        Manual         Timer    Battery Indicator           Extra Head
# 18        Manual         Pacer           Dual Speed           Attachment
# 19       Battery         Timer      Distinguishable           Dual Speed
# 20        Manual         Timer      Distinguishable        Tavel Storage
# #########################################################################
#
# Data length is: 21

# %%
records = []
for i in range(0,num_records):
    records.append([str(store_data.values[i,j]) for j in range(0,3)])

# %%
#association_rules = apriori(records,min_support=0.005, min_confidence=0.02, min_lift=3, min_length=2)
association_rules = apriori(records,min_support=0.005, min_confidence=0.02, min_lift=3, min_length=2)

association_results = list(association_rules)
item_num = len(association_results)

# %%
print(len(association_results))
# Out:
# 15

# %%
#print(association_results[0]
for x in range(0, item_num):
    print(association_results[x])
    print("###########################################################")
# Out:
# RelationRecord(items=frozenset({'Attachments', 'Warranty'}), support=0.047619047619047616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Attachments'}), items_add=frozenset({'Warranty'}), confidence=1.0, lift=10.5), OrderedStatistic(items_base=frozenset({'Warranty'}), items_add=frozenset({'Attachments'}), confidence=0.5, lift=10.5)])
# ###########################################################
# RelationRecord(items=frozenset({'Battery', 'Charity'}), support=0.047619047619047616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Battery'}), items_add=frozenset({'Charity'}), confidence=0.3333333333333333, lift=7.0), OrderedStatistic(items_base=frozenset({'Charity'}), items_add=frozenset({'Battery'}), confidence=1.0, lift=7.0)])
# ###########################################################
# RelationRecord(items=frozenset({'Battery', 'Distinguishable'}), support=0.047619047619047616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Battery'}), items_add=frozenset({'Distinguishable'}), confidence=0.3333333333333333, lift=3.5), OrderedStatistic(items_base=frozenset({'Distinguishable'}), items_add=frozenset({'Battery'}), confidence=0.5, lift=3.5)])
# ###########################################################
# RelationRecord(items=frozenset({'Built-in Toothpaste', 'Head Storage'}), support=0.047619047619047616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Built-in Toothpaste'}), items_add=frozenset({'Head Storage'}), confidence=1.0, lift=21.0), OrderedStatistic(items_base=frozenset({'Head Storage'}), items_add=frozenset({'Built-in Toothpaste'}), confidence=1.0, lift=21.0)])
# ###########################################################
# RelationRecord(items=frozenset({'Dual Speed', 'Charity'}), support=0.047619047619047616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Charity'}), items_add=frozenset({'Dual Speed'}), confidence=1.0, lift=5.25), OrderedStatistic(items_base=frozenset({'Dual Speed'}), items_add=frozenset({'Charity'}), confidence=0.25, lift=5.25)])
# ###########################################################
# RelationRecord(items=frozenset({'Timer', 'Distinguishable'}), support=0.09523809523809523, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Distinguishable'}), items_add=frozenset({'Timer'}), confidence=1.0, lift=3.5), OrderedStatistic(items_base=frozenset({'Timer'}), items_add=frozenset({'Distinguishable'}), confidence=0.3333333333333333, lift=3.5)])
# ###########################################################
# RelationRecord(items=frozenset({'Dual Speed', 'Pacer'}), support=0.047619047619047616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Dual Speed'}), items_add=frozenset({'Pacer'}), confidence=0.25, lift=5.25), OrderedStatistic(items_base=frozenset({'Pacer'}), items_add=frozenset({'Dual Speed'}), confidence=1.0, lift=5.25)])
# ###########################################################
# RelationRecord(items=frozenset({'Attachments', 'Warranty', 'Manual'}), support=0.047619047619047616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Attachments'}), items_add=frozenset({'Warranty', 'Manual'}), confidence=1.0, lift=10.5), OrderedStatistic(items_base=frozenset({'Warranty'}), items_add=frozenset({'Attachments', 'Manual'}), confidence=0.5, lift=10.5), OrderedStatistic(items_base=frozenset({'Attachments', 'Manual'}), items_add=frozenset({'Warranty'}), confidence=1.0, lift=10.5), OrderedStatistic(items_base=frozenset({'Warranty', 'Manual'}), items_add=frozenset({'Attachments'}), confidence=0.5, lift=10.5)])
# ###########################################################
# RelationRecord(items=frozenset({'Battery', 'Dual Speed', 'Charity'}), support=0.047619047619047616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Battery'}), items_add=frozenset({'Dual Speed', 'Charity'}), confidence=0.3333333333333333, lift=7.0), OrderedStatistic(items_base=frozenset({'Charity'}), items_add=frozenset({'Battery', 'Dual Speed'}), confidence=1.0, lift=21.0), OrderedStatistic(items_base=frozenset({'Dual Speed'}), items_add=frozenset({'Battery', 'Charity'}), confidence=0.25, lift=5.25), OrderedStatistic(items_base=frozenset({'Battery', 'Charity'}), items_add=frozenset({'Dual Speed'}), confidence=1.0, lift=5.25), OrderedStatistic(items_base=frozenset({'Battery', 'Dual Speed'}), items_add=frozenset({'Charity'}), confidence=1.0, lift=21.0), OrderedStatistic(items_base=frozenset({'Dual Speed', 'Charity'}), items_add=frozenset({'Battery'}), confidence=1.0, lift=7.0)])
# ###########################################################
# RelationRecord(items=frozenset({'Battery', 'Timer', 'Distinguishable'}), support=0.047619047619047616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Battery'}), items_add=frozenset({'Timer', 'Distinguishable'}), confidence=0.3333333333333333, lift=3.5), OrderedStatistic(items_base=frozenset({'Distinguishable'}), items_add=frozenset({'Battery', 'Timer'}), confidence=0.5, lift=5.25), OrderedStatistic(items_base=frozenset({'Timer'}), items_add=frozenset({'Battery', 'Distinguishable'}), confidence=0.16666666666666666, lift=3.5), OrderedStatistic(items_base=frozenset({'Battery', 'Distinguishable'}), items_add=frozenset({'Timer'}), confidence=1.0, lift=3.5), OrderedStatistic(items_base=frozenset({'Battery', 'Timer'}), items_add=frozenset({'Distinguishable'}), confidence=0.5, lift=5.25), OrderedStatistic(items_base=frozenset({'Timer', 'Distinguishable'}), items_add=frozenset({'Battery'}), confidence=0.5, lift=3.5)])
# ###########################################################
# RelationRecord(items=frozenset({'Battery', 'Timer', 'Style'}), support=0.047619047619047616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Battery'}), items_add=frozenset({'Timer', 'Style'}), confidence=0.3333333333333333, lift=7.0), OrderedStatistic(items_base=frozenset({'Timer'}), items_add=frozenset({'Battery', 'Style'}), confidence=0.16666666666666666, lift=3.5), OrderedStatistic(items_base=frozenset({'Battery', 'Style'}), items_add=frozenset({'Timer'}), confidence=1.0, lift=3.5), OrderedStatistic(items_base=frozenset({'Timer', 'Style'}), items_add=frozenset({'Battery'}), confidence=1.0, lift=7.0)])
# ###########################################################
# RelationRecord(items=frozenset({'Manual', 'Built-in Toothpaste', 'Head Storage'}), support=0.047619047619047616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Built-in Toothpaste'}), items_add=frozenset({'Manual', 'Head Storage'}), confidence=1.0, lift=21.0), OrderedStatistic(items_base=frozenset({'Head Storage'}), items_add=frozenset({'Manual', 'Built-in Toothpaste'}), confidence=1.0, lift=21.0), OrderedStatistic(items_base=frozenset({'Manual', 'Built-in Toothpaste'}), items_add=frozenset({'Head Storage'}), confidence=1.0, lift=21.0), OrderedStatistic(items_base=frozenset({'Manual', 'Head Storage'}), items_add=frozenset({'Built-in Toothpaste'}), confidence=1.0, lift=21.0)])
# ###########################################################
# RelationRecord(items=frozenset({'Timer', 'Manual', 'Distinguishable'}), support=0.047619047619047616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Timer'}), items_add=frozenset({'Manual', 'Distinguishable'}), confidence=0.16666666666666666, lift=3.5), OrderedStatistic(items_base=frozenset({'Manual', 'Distinguishable'}), items_add=frozenset({'Timer'}), confidence=1.0, lift=3.5)])
# ###########################################################
# RelationRecord(items=frozenset({'Dual Speed', 'Manual', 'Pacer'}), support=0.047619047619047616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Dual Speed'}), items_add=frozenset({'Pacer', 'Manual'}), confidence=0.25, lift=5.25), OrderedStatistic(items_base=frozenset({'Pacer'}), items_add=frozenset({'Dual Speed', 'Manual'}), confidence=1.0, lift=7.0), OrderedStatistic(items_base=frozenset({'Dual Speed', 'Manual'}), items_add=frozenset({'Pacer'}), confidence=0.3333333333333333, lift=7.0), OrderedStatistic(items_base=frozenset({'Pacer', 'Manual'}), items_add=frozenset({'Dual Speed'}), confidence=1.0, lift=5.25)])
# ###########################################################
# RelationRecord(items=frozenset({'Dual Speed', 'Warranty', 'Manual'}), support=0.047619047619047616, ordered_statistics=[OrderedStatistic(items_base=frozenset({'Warranty'}), items_add=frozenset({'Dual Speed', 'Manual'}), confidence=0.5, lift=3.5), OrderedStatistic(items_base=frozenset({'Dual Speed', 'Manual'}), items_add=frozenset({'Warranty'}), confidence=0.3333333333333333, lift=3.5)])
# ###########################################################

# %%
#print("Results:")
#for item in association_results:
    
#    pair = item[0]
#    items = [x for x in pair]
#    print("Rule:" + items[0] + "->" + items[1])
    
#    print("Support:" + str(item[1]))
    
    
#    print("Confidence:"+ str(item[2][0][2]))
#    print("Lift:" + str(item[2][0][3]))
#    print("=================================")

# %%
results = []
for item in association_results:
    pair = item[0]
    items = [x for x in pair]
    
    value0 = str(items[0])
    value1 = str(items[1])
    value2 = str(item[1])[:7]
    value3 = str(item[2][0][2])[:7]
    value4 = str(item[2][0][3])[:7]
    
    rows = (value0, value1,value2, value3, value4)
    results.append(rows)
    
    Label = ['Title 1', '    Title 2', ' Suppoert', 'Confidence', '  Lift']
    
    store_suggestion = pd.DataFrame.from_records(results,columns=Label)
    print("#####################################################")
    print(store_suggestion)
# Out:
# #####################################################
#        Title 1     Title 2  Suppoert Confidence   Lift
# 0  Attachments    Warranty   0.04761        1.0   10.5
# #####################################################
#        Title 1     Title 2  Suppoert Confidence   Lift
# 0  Attachments    Warranty   0.04761        1.0   10.5
# 1      Battery     Charity   0.04761    0.33333    7.0
# #####################################################
#        Title 1          Title 2  Suppoert Confidence   Lift
# 0  Attachments         Warranty   0.04761        1.0   10.5
# 1      Battery          Charity   0.04761    0.33333    7.0
# 2      Battery  Distinguishable   0.04761    0.33333    3.5
# #####################################################
#                Title 1          Title 2  Suppoert Confidence   Lift
# 0          Attachments         Warranty   0.04761        1.0   10.5
# 1              Battery          Charity   0.04761    0.33333    7.0
# 2              Battery  Distinguishable   0.04761    0.33333    3.5
# 3  Built-in Toothpaste     Head Storage   0.04761        1.0   21.0
# #####################################################
#                Title 1          Title 2  Suppoert Confidence   Lift
# 0          Attachments         Warranty   0.04761        1.0   10.5
# 1              Battery          Charity   0.04761    0.33333    7.0
# 2              Battery  Distinguishable   0.04761    0.33333    3.5
# 3  Built-in Toothpaste     Head Storage   0.04761        1.0   21.0
# 4           Dual Speed          Charity   0.04761        1.0   5.25
# #####################################################
#                Title 1          Title 2  Suppoert Confidence   Lift
# 0          Attachments         Warranty   0.04761        1.0   10.5
# 1              Battery          Charity   0.04761    0.33333    7.0
# 2              Battery  Distinguishable   0.04761    0.33333    3.5
# 3  Built-in Toothpaste     Head Storage   0.04761        1.0   21.0
# 4           Dual Speed          Charity   0.04761        1.0   5.25
# 5                Timer  Distinguishable   0.09523        1.0    3.5
# #####################################################
#                Title 1          Title 2  Suppoert Confidence   Lift
# 0          Attachments         Warranty   0.04761        1.0   10.5
# 1              Battery          Charity   0.04761    0.33333    7.0
# 2              Battery  Distinguishable   0.04761    0.33333    3.5
# 3  Built-in Toothpaste     Head Storage   0.04761        1.0   21.0
# 4           Dual Speed          Charity   0.04761        1.0   5.25
# 5                Timer  Distinguishable   0.09523        1.0    3.5
# 6           Dual Speed            Pacer   0.04761       0.25   5.25
# #####################################################
#                Title 1          Title 2  Suppoert Confidence   Lift
# 0          Attachments         Warranty   0.04761        1.0   10.5
# 1              Battery          Charity   0.04761    0.33333    7.0
# 2              Battery  Distinguishable   0.04761    0.33333    3.5
# 3  Built-in Toothpaste     Head Storage   0.04761        1.0   21.0
# 4           Dual Speed          Charity   0.04761        1.0   5.25
# 5                Timer  Distinguishable   0.09523        1.0    3.5
# 6           Dual Speed            Pacer   0.04761       0.25   5.25
# 7          Attachments         Warranty   0.04761        1.0   10.5
# #####################################################
#                Title 1          Title 2  Suppoert Confidence   Lift
# 0          Attachments         Warranty   0.04761        1.0   10.5
# 1              Battery          Charity   0.04761    0.33333    7.0
# 2              Battery  Distinguishable   0.04761    0.33333    3.5
# 3  Built-in Toothpaste     Head Storage   0.04761        1.0   21.0
# 4           Dual Speed          Charity   0.04761        1.0   5.25
# 5                Timer  Distinguishable   0.09523        1.0    3.5
# 6           Dual Speed            Pacer   0.04761       0.25   5.25
# 7          Attachments         Warranty   0.04761        1.0   10.5
# 8              Battery       Dual Speed   0.04761    0.33333    7.0
# #####################################################
#                Title 1          Title 2  Suppoert Confidence   Lift
# 0          Attachments         Warranty   0.04761        1.0   10.5
# 1              Battery          Charity   0.04761    0.33333    7.0
# 2              Battery  Distinguishable   0.04761    0.33333    3.5
# 3  Built-in Toothpaste     Head Storage   0.04761        1.0   21.0
# 4           Dual Speed          Charity   0.04761        1.0   5.25
# 5                Timer  Distinguishable   0.09523        1.0    3.5
# 6           Dual Speed            Pacer   0.04761       0.25   5.25
# 7          Attachments         Warranty   0.04761        1.0   10.5
# 8              Battery       Dual Speed   0.04761    0.33333    7.0
# 9              Battery            Timer   0.04761    0.33333    3.5
# #####################################################
#                 Title 1          Title 2  Suppoert Confidence   Lift
# 0           Attachments         Warranty   0.04761        1.0   10.5
# 1               Battery          Charity   0.04761    0.33333    7.0
# 2               Battery  Distinguishable   0.04761    0.33333    3.5
# 3   Built-in Toothpaste     Head Storage   0.04761        1.0   21.0
# 4            Dual Speed          Charity   0.04761        1.0   5.25
# 5                 Timer  Distinguishable   0.09523        1.0    3.5
# 6            Dual Speed            Pacer   0.04761       0.25   5.25
# 7           Attachments         Warranty   0.04761        1.0   10.5
# 8               Battery       Dual Speed   0.04761    0.33333    7.0
# 9               Battery            Timer   0.04761    0.33333    3.5
# 10              Battery            Timer   0.04761    0.33333    7.0
# #####################################################
#                 Title 1              Title 2  Suppoert Confidence   Lift
# 0           Attachments             Warranty   0.04761        1.0   10.5
# 1               Battery              Charity   0.04761    0.33333    7.0
# 2               Battery      Distinguishable   0.04761    0.33333    3.5
# 3   Built-in Toothpaste         Head Storage   0.04761        1.0   21.0
# 4            Dual Speed              Charity   0.04761        1.0   5.25
# 5                 Timer      Distinguishable   0.09523        1.0    3.5
# 6            Dual Speed                Pacer   0.04761       0.25   5.25
# 7           Attachments             Warranty   0.04761        1.0   10.5
# 8               Battery           Dual Speed   0.04761    0.33333    7.0
# 9               Battery                Timer   0.04761    0.33333    3.5
# 10              Battery                Timer   0.04761    0.33333    7.0
# 11               Manual  Built-in Toothpaste   0.04761        1.0   21.0
# #####################################################
#                 Title 1              Title 2  Suppoert Confidence   Lift
# 0           Attachments             Warranty   0.04761        1.0   10.5
# 1               Battery              Charity   0.04761    0.33333    7.0
# 2               Battery      Distinguishable   0.04761    0.33333    3.5
# 3   Built-in Toothpaste         Head Storage   0.04761        1.0   21.0
# 4            Dual Speed              Charity   0.04761        1.0   5.25
# 5                 Timer      Distinguishable   0.09523        1.0    3.5
# 6            Dual Speed                Pacer   0.04761       0.25   5.25
# 7           Attachments             Warranty   0.04761        1.0   10.5
# 8               Battery           Dual Speed   0.04761    0.33333    7.0
# 9               Battery                Timer   0.04761    0.33333    3.5
# 10              Battery                Timer   0.04761    0.33333    7.0
# 11               Manual  Built-in Toothpaste   0.04761        1.0   21.0
# 12                Timer               Manual   0.04761    0.16666    3.5
# #####################################################
#                 Title 1              Title 2  Suppoert Confidence   Lift
# 0           Attachments             Warranty   0.04761        1.0   10.5
# 1               Battery              Charity   0.04761    0.33333    7.0
# 2               Battery      Distinguishable   0.04761    0.33333    3.5
# 3   Built-in Toothpaste         Head Storage   0.04761        1.0   21.0
# 4            Dual Speed              Charity   0.04761        1.0   5.25
# 5                 Timer      Distinguishable   0.09523        1.0    3.5
# 6            Dual Speed                Pacer   0.04761       0.25   5.25
# 7           Attachments             Warranty   0.04761        1.0   10.5
# 8               Battery           Dual Speed   0.04761    0.33333    7.0
# 9               Battery                Timer   0.04761    0.33333    3.5
# 10              Battery                Timer   0.04761    0.33333    7.0
# 11               Manual  Built-in Toothpaste   0.04761        1.0   21.0
# 12                Timer               Manual   0.04761    0.16666    3.5
# 13           Dual Speed               Manual   0.04761       0.25   5.25
# #####################################################
#                 Title 1              Title 2  Suppoert Confidence   Lift
# 0           Attachments             Warranty   0.04761        1.0   10.5
# 1               Battery              Charity   0.04761    0.33333    7.0
# 2               Battery      Distinguishable   0.04761    0.33333    3.5
# 3   Built-in Toothpaste         Head Storage   0.04761        1.0   21.0
# 4            Dual Speed              Charity   0.04761        1.0   5.25
# 5                 Timer      Distinguishable   0.09523        1.0    3.5
# 6            Dual Speed                Pacer   0.04761       0.25   5.25
# 7           Attachments             Warranty   0.04761        1.0   10.5
# 8               Battery           Dual Speed   0.04761    0.33333    7.0
# 9               Battery                Timer   0.04761    0.33333    3.5
# 10              Battery                Timer   0.04761    0.33333    7.0
# 11               Manual  Built-in Toothpaste   0.04761        1.0   21.0
# 12                Timer               Manual   0.04761    0.16666    3.5
# 13           Dual Speed               Manual   0.04761       0.25   5.25
# 14           Dual Speed             Warranty   0.04761        0.5    3.5
